# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Input

# %%
# Load dataset
data = pd.read_csv('candy.csv')

# %%
# Extract features and target
X = data.drop(columns=["competitorname", "winpercent"]).values
y = data["winpercent"].values

# %%
# Manually perform Min-Max scaling (0-1 normalization)
X_min = np.min(X, axis=0)
X_max = np.max(X, axis=0)
X_scaled = (X - X_min) / (X_max - X_min)

# %%
# Reshape the data for CNN input: (samples, num_features, 1)
num_samples, num_features = X_scaled.shape
X_reshaped = X_scaled.reshape(num_samples, num_features, 1)

# %%
# Manually split the data into training and testing sets (80-20 split)
split_index = int(0.8 * num_samples)
X_train, X_test = X_reshaped[:split_index], X_reshaped[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %%
# model architecture
model = Sequential([
    Input(shape=(num_features, 1)),
    Conv1D(32, kernel_size=2, activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1)
])

# %%
# Compile the model with a lower learning rate for better convergence
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model for 50 epochs
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 630ms/step - loss: 2840.3982 - val_loss: 2915.6077
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2890.7136 - val_loss: 2895.5586
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2832.0115 - val_loss: 2874.0779
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2754.5056 - val_loss: 2851.3494
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2845.1536 - val_loss: 2827.1965
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2756.9524 - val_loss: 2800.6130
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2756.3408 - val_loss: 2771.7808
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2795.7759 - val_loss: 2740.1526
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2686.5510 - val_loss: 2705.6743
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2618.1987 - val_loss: 2668.1858
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2615.5771 - val_loss: 2627.2908
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2568.9758 - val_loss: 2582.7065
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2421.9656 - val_loss: 2534.2522
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2404.4214 - val_loss: 2481.9937
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2440.2654 - val_loss: 2425.7908
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2283.0645 - val_loss: 2365.7700
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2355.8657 - val_loss: 2301.7163
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2239.7981 - val_loss: 2233.6199
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2139.4868 - val_loss: 2161.4255
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2128.5459 - val_loss: 2085.2976
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2062.5681 - val_loss: 2005.3640
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2017.9149 - val_loss: 1921.8373
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1894.9513 - val_loss: 1834.7560
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1835.3378 - val_loss: 1744.5381
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1716.5514 - val_loss: 1650.9393
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1624.3602 - val_loss: 1555.0148
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1585.3584 - val_loss: 1456.8049
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1514.9462 - val_loss: 1357.0441
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1333.6429 - val_loss: 1256.4290
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1307.4706 - val_loss: 1155.1588
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1183.7493 - val_loss: 1054.4718
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1062.1752 - val_loss: 955.1496
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 923.6952 - val_loss: 858.1127
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 856.3222 - val_loss: 763.4071
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 815.5350 - val_loss: 672.1794
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 755.4526 - val_loss: 586.3498
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 669.9018 - val_loss: 507.2639
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 586.4072 - val_loss: 435.6884
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 525.3771 - val_loss: 372.4160
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 455.0447 - val_loss: 317.9030
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 371.2300 - val_loss: 272.2914
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 314.7973 - val_loss: 235.4795
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 260.1888 - val_loss: 207.2570
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 282.1653 - val_loss: 187.3081
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 259.3980 - val_loss: 174.9295
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 228.6092 - val_loss: 169.0150
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 215.4278 - val_loss: 168.0536
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 221.0054 - val_loss: 170.5477
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 211.3354 - val_loss: 175.0330
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 197.1420 - val_loss: 180.3473

# %%
# Evaluate the model
test_loss = model.evaluate(X_test, y_test, verbose=0)

print(f'Test Loss: {test_loss}')
# Out:
# Test Loss: 135.22216796875

# %%
import matplotlib.pyplot as plt

# Generate predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step

# %%
# Plot the actual vs predicted values using a line plot
plt.figure(figsize=(10,6))
plt.plot(y_test, label="Actual Winpercent", color='blue')
plt.plot(y_pred, label="Predicted Winpercent", color='red', linestyle='dashed')
plt.xlabel("Samples")
plt.ylabel("Winpercent")
plt.title("Actual vs Predicted Winpercent - Line Plot")
plt.legend()
plt.show()

# %%
# Plot the training and validation loss over epochs
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss over Epochs")
plt.legend()
plt.show()
